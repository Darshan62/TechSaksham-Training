# %%
#Importing the required libraries
import pandas as pd 
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Opening the dataset
df = pd.read_csv(r"deliveries.csv")
df
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
#First 5 values in dataset
df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
#Last 5 values in dataset
df.tail()
# Out:
#         match_id  inning           batting_team         bowling_team  over  \
# 260915   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260916   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260917   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260918   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260919   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
#
#         ball   batter         bowler non_striker  batsman_runs  extra_runs  \
# 260915     5  SS Iyer     AK Markram     VR Iyer             1           0
# 260916     6  VR Iyer     AK Markram     SS Iyer             1           0
# 260917     1  VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 260918     2  SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 260919     3  VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
# ...

# %%
#Data types and all Information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
# ...

# %%
#Describe dataset & Displays only the Numerical/integer values

df.describe()
# Out:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
 #Checking the duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
#Checking how many columns are present
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#Top 10 Highest Run Scorers in IPL
top_scorers = df.groupby('batter')['batsman_runs'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=top_scorers.index, y=top_scorers.values,palette='magma')
plt.xlabel("Batsmen")
plt.ylabel("Total Runs")
plt.title("Top 10 Highest Run Scorers in IPL")
plt.xticks(rotation=45)
plt.show()

# %%
#Most Common Dismissals in IPL
dismissal_types = df['dismissal_kind'].value_counts()

plt.figure(figsize=(8,4))
sns.barplot(x=dismissal_types.index, y=dismissal_types.values, palette='plasma')
plt.xlabel("Dismissal Type")
plt.ylabel("Count")
plt.title("Most Common Dismissals in IPL")
plt.xticks(rotation=45)
plt.show()

# %%
#Runs Scored in Each Over (Powerplay vs Death Overs)
over_wise_runs = df.groupby('over')['total_runs'].sum()

plt.figure(figsize=(10,5))
sns.lineplot(x=over_wise_runs.index, y=over_wise_runs.values, marker='o', color='blue')
plt.xlabel("Over Number")
plt.ylabel("Total Runs")
plt.title("Runs Scored in Each Over (Powerplay vs Death Overs)")
plt.xticks(range(1, 21))
plt.grid(True)
plt.show()

# %%
# Scatter Plot of Runs Scored vs. Overs
plt.figure(figsize=(10, 5))
plt.scatter(df['over'], df['batsman_runs'], alpha=0.5, color='blue')

# Labels and Title
plt.xlabel("Over", fontsize=12)
plt.ylabel("Runs Scored", fontsize=12)
plt.title("Scatter Plot of Runs Scored vs. Overs", fontsize=14)
plt.show()

# %%
# Function to create a bar plot for categorical columns
def bar_plot(variable):
    var = df[variable]
    varValue = var.value_counts()  # Count occurrences of each category
    plt.figure(figsize=(10, 5))
    plt.bar(varValue.index, varValue, color='skyblue')  # Bar plot
    plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for readability
    plt.ylabel("Frequency", fontsize=12)
    plt.xlabel(variable, fontsize=12)
    plt.title(f"Bar Plot of {variable}", fontsize=14)
    plt.show()
    print(f"{variable}: \n{varValue}")

# List of categorical columns to visualize
columns_plot = ['batting_team', 'bowling_team', 'dismissal_kind', 'extras_type']

# Generate bar plots for each selected column
for i in columns_plot:
    bar_plot(i)
# Out:
# batting_team:
# batting_team
# Mumbai Indians                 31437
# Kolkata Knight Riders          29514
# Chennai Super Kings            28651
# Royal Challengers Bangalore    28205
# Rajasthan Royals               26242
# Kings XI Punjab                22646
# Sunrisers Hyderabad            21843
# Delhi Daredevils               18786
# Delhi Capitals                 10946
# Deccan Chargers                 9034
# Punjab Kings                    6833
# Gujarat Titans                  5494
# Pune Warriors                   5443
# Lucknow Super Giants            5400
# Gujarat Lions                   3566
# Rising Pune Supergiant          1900
# Royal Challengers Bengaluru     1818
# Kochi Tuskers Kerala            1582
# Rising Pune Supergiants         1580
# Name: count, dtype: int64
# bowling_team:
# bowling_team
# Mumbai Indians                 31505
# Kolkata Knight Riders          29663
# Chennai Super Kings            28576
# Royal Challengers Bangalore    28358
# ...

# %%
# Function to create a histogram for numerical columns
def hist_plot(variable):
    plt.figure(figsize=(10, 5))
    plt.hist(df[variable], bins=20, color='orange', edgecolor='black')  # Histogram with bins
    plt.xlabel(variable, fontsize=12)
    plt.ylabel("Frequency", fontsize=12)
    plt.title(f"Histogram of {variable}", fontsize=14)
    plt.show()
    print(f"{variable}:\n{df[variable].describe()}")  # Print summary statistics

# List of numerical columns to visualize
columns_plot = ['batsman_runs', 'total_runs', 'extra_runs', 'over', 'ball']

# Generate histogram plots for each selected column
for i in columns_plot:
    hist_plot(i)
# Out:
# batsman_runs:
# count    260920.000000
# mean          1.265001
# std           1.639298
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           6.000000
# Name: batsman_runs, dtype: float64
# total_runs:
# count    260920.000000
# mean          1.332807
# std           1.626416
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           7.000000
# Name: total_runs, dtype: float64
# extra_runs:
# count    260920.000000
# mean          0.067806
# std           0.343265
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           7.000000
# Name: extra_runs, dtype: float64
# over:
# count    260920.000000
# mean          9.197677
# std           5.683484
# min           0.000000
# 25%           4.000000
# 50%           9.000000
# 75%          14.000000
# max          19.000000
# Name: over, dtype: float64
# ball:
# ...

# %%
sns.pairplot(df)

# %%
# Calculating mean values based on batting team performance
df[['batting_team', 'total_runs']].groupby(['batting_team'], as_index=False).mean().sort_values(by='total_runs', ascending=False)
# Out:
#                    batting_team  total_runs
# 17  Royal Challengers Bengaluru    1.611661
# 5                Gujarat Titans    1.411904
# 12                 Punjab Kings    1.395580
# 9          Lucknow Super Giants    1.390741
# 4                 Gujarat Lions    1.363432
# 2                Delhi Capitals    1.361228
# 0           Chennai Super Kings    1.348260
# 10               Mumbai Indians    1.341604
# 16  Royal Challengers Bangalore    1.336359
# 8         Kolkata Knight Riders    1.332622
# 18          Sunrisers Hyderabad    1.330907
# 6               Kings XI Punjab    1.327563
# 13             Rajasthan Royals    1.324099
# 15      Rising Pune Supergiants    1.305696
# 14       Rising Pune Supergiant    1.300000
# 3              Delhi Daredevils    1.293304
# 1               Deccan Chargers    1.268873
# 7          Kochi Tuskers Kerala    1.201643
# 11                Pune Warriors    1.168106

# %%
plt.figure(figsize=(9, 5))
sns.boxplot(data=df, x='is_wicket', y='total_runs')
plt.title("Box Plot: Wickets vs. Runs Scored")
plt.xlabel("Wicket Taken (Yes/No)")
plt.ylabel("Total Runs")
plt.show()

# %%
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %%
#Using .fillna() to Fill Missing Values
df['extras_type'].fillna("No Extra", inplace=True)
df['player_dismissed'].fillna("Not Out", inplace=True)
df['dismissal_kind'].fillna("Not Out", inplace=True)
df['fielder'].fillna("No Fielder Involved", inplace=True)

# %%
print(df.isna().sum())
# Out:
# match_id            0
# inning              0
# batting_team        0
# bowling_team        0
# over                0
# ball                0
# batter              0
# bowler              0
# non_striker         0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# extras_type         0
# is_wicket           0
# player_dismissed    0
# dismissal_kind      0
# fielder             0
# dtype: int64

# %%
to_drop = ['extras_type', 'fielder']

# Drop only if columns exist
df = df.drop(columns=[col for col in to_drop if col in df.columns], axis=1)

# %%
df = pd.get_dummies(df, columns=['batting_team', 'bowling_team', 'dismissal_kind'], drop_first=True)

# %%
# Selecting only numerical columns
numeric_df = df.select_dtypes(include=['number'])

# Creating the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(numeric_df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

for col in ['batter', 'bowler', 'non_striker', 'player_dismissed']:
    df[col] = LabelEncoder().fit_transform(df[col])
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(12, 6))
sns.heatmap(numeric_df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %%
# Counting wins when a team batted first (Inning 1)
batting_first_wins = df[df['inning'] == 1].groupby('batting_team')['match_id'].nunique()

# Convert to DataFrame
batting_first_wins = batting_first_wins.reset_index()
batting_first_wins.columns = ['Team', 'Wins']

# Plot the data
plt.figure(figsize=(12,6))
sns.barplot(x='Team', y='Wins', data=batting_first_wins, palette='Reds_r')

# Labels and title
plt.xlabel("Teams")
plt.ylabel("Total Wins")
plt.title("Total Wins When Batting First")
plt.xticks(rotation=45)
plt.show()

# %%
# Filtering matches where team batted first and won
bat_first_wins = df[df['inning'] == 1].groupby('batting_team')['match_id'].nunique().sort_values(ascending=False)

# Plot
plt.figure(figsize=(12,6))
sns.barplot(x=bat_first_wins.index, y=bat_first_wins.values, palette='Blues_r')

# Labels
plt.xlabel("Teams")
plt.ylabel("Wins when Batting First")
plt.title("Number of Matches Won by Teams When Batting First")
plt.xticks(rotation=45)
plt.show()

# %%
# Grouping by over to count wickets
wickets_per_over = df[df['is_wicket'] == 1].groupby('over')['is_wicket'].count()

# Plot
plt.figure(figsize=(12,6))
sns.barplot(x=wickets_per_over.index, y=wickets_per_over.values, palette='cividis')

# Labels
plt.xlabel("Over Number")
plt.ylabel("Total Wickets Taken")
plt.title("Most Wicket-Taking Overs in IPL")
plt.xticks(rotation=45)
plt.show()

# %%
# Group by bowling team and sum up extra runs conceded
extra_runs_by_team = df.groupby('bowling_team')['extra_runs'].sum().sort_values(ascending=False)

# Plot the extra runs conceded by teams
plt.figure(figsize=(12, 6))
sns.barplot(x=extra_runs_by_team.index, y=extra_runs_by_team.values, palette="coolwarm")

# Add labels
plt.xlabel("Teams", fontsize=12)
plt.ylabel("Total Extra Runs Conceded", fontsize=12)
plt.title("Most Extra Runs Conceded by Teams in IPL", fontsize=14)
plt.xticks(rotation=45, ha="right")

# Show plot
plt.show()
